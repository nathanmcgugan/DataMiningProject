# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_feather('mined_data.feather')

df.drop(['user_id', 'order_id', 'days_since_prior_order', 'product_id', 'order_number', 'order_dow', 'order_hour_of_day', 'reordered', 'product_name', 'days_since_user_first_order'], axis=1, inplace=True)

# -1 was used to represent first orders of a product for a user
df = df[df['days_since_user_ordered_product'] >= 0]

training_set, testing_set = train_test_split(df, test_size=0.2)

small_train, small_test  = train_test_split(training_set.sample(frac=0.1), test_size=0.2)
df.columns
# Out:
# Index(['aisle_air_fresheners_candles', 'aisle_asian_foods',
#        'aisle_baby_accessories', 'aisle_baby_bath_body_care',
#        'aisle_baby_food_formula', 'aisle_bakery_desserts',
#        'aisle_baking_ingredients', 'aisle_baking_supplies_decor',
#        'aisle_beauty', 'aisle_beers_coolers',
#        ...
#        'department_international', 'department_meat_seafood',
#        'department_missing', 'department_other', 'department_pantry',
#        'department_personal_care', 'department_pets', 'department_produce',
#        'department_snacks', 'days_since_user_ordered_product'],
#       dtype='object', length=156)

# %%
import optuna
from sklearn.metrics import mean_squared_error
import xgboost as xgb

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 0.5),
        "lambda": trial.suggest_float("lambda", 1, 10),
        "tree_method": "hist",
        "objective": "reg:squarederror",
        "device": "cuda",
        "eval_metric": "rmse"
    }
    
    xgb_model = xgb.XGBRegressor(**params)
    xgb_model.fit(small_train.drop(['days_since_user_ordered_product'], axis=1), small_train['days_since_user_ordered_product'])
    
    mse = mean_squared_error(small_test['days_since_user_ordered_product'], xgb_model.predict(small_test.drop(['days_since_user_ordered_product'], axis=1)))
    return mse

study = optuna.create_study(study_name="XGBoost", direction="minimize")
study.optimize(objective, n_trials=100)

print(study.best_params)
# Out:
# [I 2025-04-08 23:32:24,034] A new study created in memory with name: XGBoost
# C:\Users\natha\PycharmProjects\Datamining_project\.venv\Lib\site-packages\xgboost\core.py:729: UserWarning: [23:32:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# [I 2025-04-08 23:32:27,222] Trial 0 finished with value: 1309.5734216638527 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.22563621178122772, 'subsample': 0.7960577512058409, 'colsample_bytree': 0.9720860194803735, 'gamma': 0.050112938754335645, 'lambda': 9.38767706377512}. Best is trial 0 with value: 1309.5734216638527.
# [I 2025-04-08 23:32:30,390] Trial 1 finished with value: 1309.611088697999 and parameters: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.11459188516864219, 'subsample': 0.6071595868997088, 'colsample_bytree': 0.6985053336280125, 'gamma': 0.16883979385831005, 'lambda': 4.415654856867698}. Best is trial 0 with value: 1309.5734216638527.
# [I 2025-04-08 23:32:38,464] Trial 2 finished with value: 1309.6335299297505 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'learning_rate': 0.24293133749958196, 'subsample': 0.5873697280606107, 'colsample_bytree': 0.5831806165236619, 'gamma': 0.056809422293839396, 'lambda': 8.565697482015871}. Best is trial 0 with value: 1309.5734216638527.
# [I 2025-04-08 23:32:40,972] Trial 3 finished with value: 1309.5732953059305 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.15701839430789016, 'subsample': 0.6852741532757696, 'colsample_bytree': 0.7362207909730976, 'gamma': 0.3212615421337655, 'lambda': 9.84676191156258}. Best is trial 3 with value: 1309.5732953059305.
# [I 2025-04-08 23:32:42,733] Trial 4 finished with value: 1310.4434520970449 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.13391695502337891, 'subsample': 0.8102440430415592, 'colsample_bytree': 0.8312821863140103, 'gamma': 0.4148755417719451, 'lambda': 5.272036971453002}. Best is trial 3 with value: 1309.5732953059305.
# [I 2025-04-08 23:32:46,682] Trial 5 finished with value: 1309.5924875250778 and parameters: {'n_estimators': 600, 'max_depth': 4, 'learning_rate': 0.08932617747398425, 'subsample': 0.7741175019213582, 'colsample_bytree': 0.5176669869895871, 'gamma': 0.2003113618624291, 'lambda': 5.713452617961808}. Best is trial 3 with value: 1309.5732953059305.
# [I 2025-04-08 23:32:49,267] Trial 6 finished with value: 1309.5863459573034 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.26652926283339695, 'subsample': 0.95835714664505, 'colsample_bytree': 0.7168428915697961, 'gamma': 0.31918154011802036, 'lambda': 9.085317179394737}. Best is trial 3 with value: 1309.5732953059305.
# [I 2025-04-08 23:32:51,807] Trial 7 finished with value: 1309.5729574270067 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.1524113502967833, 'subsample': 0.5390500756767682, 'colsample_bytree': 0.502450661333131, 'gamma': 0.03822051544483346, 'lambda': 3.1034325424042453}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:32:58,898] Trial 8 finished with value: 1309.6649499855362 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.29271163034691877, 'subsample': 0.5896202481705621, 'colsample_bytree': 0.5883475118611599, 'gamma': 0.3035551624041729, 'lambda': 2.6469386831245076}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:04,848] Trial 9 finished with value: 1309.587310543194 and parameters: {'n_estimators': 800, 'max_depth': 8, 'learning_rate': 0.16373972828546943, 'subsample': 0.9359871212224034, 'colsample_bytree': 0.9514567314544281, 'gamma': 0.49628623995559656, 'lambda': 1.6529651272288106}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:09,899] Trial 10 finished with value: 1309.5968645529672 and parameters: {'n_estimators': 500, 'max_depth': 12, 'learning_rate': 0.024749086855196778, 'subsample': 0.5072505788406149, 'colsample_bytree': 0.859458490453243, 'gamma': 0.13618508907878496, 'lambda': 3.4626617750432893}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:13,028] Trial 11 finished with value: 1309.5932465460326 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.1745244603248842, 'subsample': 0.6742917731063713, 'colsample_bytree': 0.6445371924126463, 'gamma': 0.33124965336490086, 'lambda': 6.923381585993404}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:14,828] Trial 12 finished with value: 1309.6099058851144 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.19710050316695746, 'subsample': 0.674519591060564, 'colsample_bytree': 0.7892835051353211, 'gamma': 0.24189442080249499, 'lambda': 7.676973639475394}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:17,640] Trial 13 finished with value: 1309.6360621235679 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.08093997171499534, 'subsample': 0.5023103647970014, 'colsample_bytree': 0.500560757150378, 'gamma': 0.0008367424060840983, 'lambda': 1.153603151094904}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:21,480] Trial 14 finished with value: 1309.6182713492872 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.03899124969425938, 'subsample': 0.6939815292313815, 'colsample_bytree': 0.8963150853310393, 'gamma': 0.4122069483409776, 'lambda': 6.554566243686415}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:26,631] Trial 15 finished with value: 1309.5818448460882 and parameters: {'n_estimators': 700, 'max_depth': 7, 'learning_rate': 0.19972160491474356, 'subsample': 0.8814512613697667, 'colsample_bytree': 0.6519797878597129, 'gamma': 0.12319404758586758, 'lambda': 3.378485499148435}. Best is trial 7 with value: 1309.5729574270067.
# [I 2025-04-08 23:33:29,201] Trial 16 finished with value: 1309.5624527041905 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.11510453723778305, 'subsample': 0.7180818270451506, 'colsample_bytree': 0.7628358760237797, 'gamma': 0.247606860177572, 'lambda': 9.995577592487635}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:31,186] Trial 17 finished with value: 1309.888272358509 and parameters: {'n_estimators': 100, 'max_depth': 12, 'learning_rate': 0.06538533082645456, 'subsample': 0.8674380153343906, 'colsample_bytree': 0.8062770254981472, 'gamma': 0.09650118722202247, 'lambda': 4.450255333223672}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:35,063] Trial 18 finished with value: 1309.5931742495845 and parameters: {'n_estimators': 400, 'max_depth': 10, 'learning_rate': 0.11291033802675815, 'subsample': 0.7328590984530703, 'colsample_bytree': 0.7594569310450111, 'gamma': 0.2290115777671499, 'lambda': 2.223917986130871}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:37,616] Trial 19 finished with value: 1309.5714511796668 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.12826250181894192, 'subsample': 0.5498019036021945, 'colsample_bytree': 0.6571259566990919, 'gamma': 0.412033044537617, 'lambda': 7.603405458528208}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:41,609] Trial 20 finished with value: 1309.5966510819248 and parameters: {'n_estimators': 400, 'max_depth': 11, 'learning_rate': 0.04806465821912087, 'subsample': 0.6291403687153596, 'colsample_bytree': 0.678870093190805, 'gamma': 0.39209526564165514, 'lambda': 8.167480978028777}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:44,188] Trial 21 finished with value: 1309.576980583922 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.13166821076650448, 'subsample': 0.5481648616455869, 'colsample_bytree': 0.591218878975043, 'gamma': 0.4930532096227327, 'lambda': 7.111019316830656}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:46,793] Trial 22 finished with value: 1309.5930313693075 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.10387316985718453, 'subsample': 0.5265950049490626, 'colsample_bytree': 0.5485525352530165, 'gamma': 0.28199291136245724, 'lambda': 5.893023708406983}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:49,964] Trial 23 finished with value: 1309.5869257597353 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.1465996617814746, 'subsample': 0.5562931474739272, 'colsample_bytree': 0.6359233783712764, 'gamma': 0.356829815511308, 'lambda': 7.903837256150115}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:51,724] Trial 24 finished with value: 1309.7194060981851 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.13223660088397132, 'subsample': 0.6365830586576933, 'colsample_bytree': 0.7811606949107345, 'gamma': 0.4492563915007488, 'lambda': 8.693963003273568}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:54,335] Trial 25 finished with value: 1309.5661587800805 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.1879377493948363, 'subsample': 0.7210087837620422, 'colsample_bytree': 0.894671313061, 'gamma': 0.1823291103828686, 'lambda': 4.977970263854079}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:33:58,439] Trial 26 finished with value: 1309.5908180532174 and parameters: {'n_estimators': 400, 'max_depth': 12, 'learning_rate': 0.18585410964120078, 'subsample': 0.7252718027394356, 'colsample_bytree': 0.9356602289332903, 'gamma': 0.19878902649126257, 'lambda': 4.391018821447716}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:34:03,736] Trial 27 finished with value: 1309.5835987760886 and parameters: {'n_estimators': 600, 'max_depth': 11, 'learning_rate': 0.22275586823579122, 'subsample': 0.8564253034129786, 'colsample_bytree': 0.8957127947837729, 'gamma': 0.26783168465889423, 'lambda': 6.36345601116575}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:34:10,541] Trial 28 finished with value: 1309.5871159702103 and parameters: {'n_estimators': 800, 'max_depth': 11, 'learning_rate': 0.08566425693947809, 'subsample': 0.9962943374432157, 'colsample_bytree': 0.853637802744932, 'gamma': 0.17948663641162813, 'lambda': 5.0674607677523}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:34:13,503] Trial 29 finished with value: 1309.57919350938 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.22155955318744064, 'subsample': 0.8194274441836471, 'colsample_bytree': 0.9919290966823487, 'gamma': 0.3682070247303577, 'lambda': 9.962854409023972}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:34:15,459] Trial 30 finished with value: 1309.5768825086902 and parameters: {'n_estimators': 100, 'max_depth': 12, 'learning_rate': 0.20293165683418868, 'subsample': 0.7667049682245188, 'colsample_bytree': 0.7476893277641747, 'gamma': 0.22759831248571197, 'lambda': 9.298861838234624}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:34:18,015] Trial 31 finished with value: 1309.5762077423608 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.17167546043048496, 'subsample': 0.6393245472325966, 'colsample_bytree': 0.9040356874828858, 'gamma': 0.059654706219263776, 'lambda': 3.395328378483656}. Best is trial 16 with value: 1309.5624527041905.
# [I 2025-04-08 23:34:20,594] Trial 32 finished with value: 1309.560468341378 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.14314077695939958, 'subsample': 0.5579927518315585, 'colsample_bytree': 0.5445141978284647, 'gamma': 0.1432397246728671, 'lambda': 3.8439856627444056}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:23,835] Trial 33 finished with value: 1309.587790717161 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.1126768758073059, 'subsample': 0.5689153964618704, 'colsample_bytree': 0.6802495607776212, 'gamma': 0.14468650178851958, 'lambda': 3.982418814695511}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:28,506] Trial 34 finished with value: 1309.597239302011 and parameters: {'n_estimators': 500, 'max_depth': 11, 'learning_rate': 0.13734452202014547, 'subsample': 0.603709898394272, 'colsample_bytree': 0.62102483309512, 'gamma': 0.10738589633987305, 'lambda': 4.787492363672134}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:30,975] Trial 35 finished with value: 1309.602998889163 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.09957153058639015, 'subsample': 0.7080885310569938, 'colsample_bytree': 0.5565830583722359, 'gamma': 0.1620084705048633, 'lambda': 7.427362044354532}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:32,875] Trial 36 finished with value: 1309.782778721945 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.12291412832347706, 'subsample': 0.6491008808871475, 'colsample_bytree': 0.7152930608106449, 'gamma': 0.20711041122686824, 'lambda': 5.67966414773968}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:35,355] Trial 37 finished with value: 1309.7286885010342 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.15330155053158118, 'subsample': 0.754771953584651, 'colsample_bytree': 0.6085386101631466, 'gamma': 0.26699728673684053, 'lambda': 8.635553372302049}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:37,971] Trial 38 finished with value: 1309.6489405592017 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.06603291472666302, 'subsample': 0.5769568864133842, 'colsample_bytree': 0.5422313698430706, 'gamma': 0.17162555935527177, 'lambda': 6.131211644760181}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:39,818] Trial 39 finished with value: 1309.5903397568093 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.2525246245853736, 'subsample': 0.8051119236370776, 'colsample_bytree': 0.8246288088558041, 'gamma': 0.0975471844370075, 'lambda': 4.106377918092397}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:43,116] Trial 40 finished with value: 1309.5998871190602 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.17400127212103922, 'subsample': 0.7847350001254153, 'colsample_bytree': 0.6771048766938472, 'gamma': 0.30231994831167175, 'lambda': 5.268394752304085}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:45,522] Trial 41 finished with value: 1309.567753745105 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.14853492881036112, 'subsample': 0.5414879290578282, 'colsample_bytree': 0.5177838061758906, 'gamma': 0.03044580174789069, 'lambda': 3.024234253079654}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:48,012] Trial 42 finished with value: 1309.5773789105951 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.1418957704381354, 'subsample': 0.5284359463872904, 'colsample_bytree': 0.5303282855757739, 'gamma': 0.07064225792699946, 'lambda': 2.966249665946293}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:51,137] Trial 43 finished with value: 1309.5822892367123 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.1571082142326195, 'subsample': 0.5968779663089914, 'colsample_bytree': 0.5710311727886425, 'gamma': 0.1992700411902767, 'lambda': 2.3626955530951097}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:52,896] Trial 44 finished with value: 1309.8649637009178 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.11854330977244362, 'subsample': 0.6209628555911915, 'colsample_bytree': 0.5248708947604612, 'gamma': 0.0783562864058065, 'lambda': 3.7064079349060233}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:55,359] Trial 45 finished with value: 1309.5798701106994 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.18248557605281335, 'subsample': 0.6614073225355696, 'colsample_bytree': 0.7294210610476645, 'gamma': 0.028360889202164397, 'lambda': 9.708933345592989}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:34:57,890] Trial 46 finished with value: 1309.5784682685737 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.16243877534688841, 'subsample': 0.5647628377353496, 'colsample_bytree': 0.569629134431313, 'gamma': 0.017197546291851554, 'lambda': 4.6737786716122285}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:01,255] Trial 47 finished with value: 1309.591276814942 and parameters: {'n_estimators': 300, 'max_depth': 11, 'learning_rate': 0.09542335045328543, 'subsample': 0.5421782606194089, 'colsample_bytree': 0.590260076286717, 'gamma': 0.1500046395043258, 'lambda': 2.814405125122212}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:07,733] Trial 48 finished with value: 1309.6298183664521 and parameters: {'n_estimators': 900, 'max_depth': 7, 'learning_rate': 0.2104373339033652, 'subsample': 0.5185940088474741, 'colsample_bytree': 0.5091787159004775, 'gamma': 0.24497598381687727, 'lambda': 1.5315008705875406}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:12,226] Trial 49 finished with value: 1309.6125255210973 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.24095190344347445, 'subsample': 0.7000228241581348, 'colsample_bytree': 0.845181469399309, 'gamma': 0.12906617966197959, 'lambda': 8.98665970340104}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:14,094] Trial 50 finished with value: 1309.6159416707608 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.18356609746989966, 'subsample': 0.5000145152287653, 'colsample_bytree': 0.7691259985338657, 'gamma': 0.4601436423254349, 'lambda': 6.751283254250232}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:16,584] Trial 51 finished with value: 1309.6102307680499 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.14865792107480386, 'subsample': 0.5878715490532793, 'colsample_bytree': 0.5130700940046562, 'gamma': 0.03589404643693439, 'lambda': 3.0619488214109456}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:19,045] Trial 52 finished with value: 1309.575355589849 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.12409784822016659, 'subsample': 0.6131390016368827, 'colsample_bytree': 0.5005350305735496, 'gamma': 0.010197005477197096, 'lambda': 3.8789722777872884}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:22,167] Trial 53 finished with value: 1309.5932783684445 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.1659807989434296, 'subsample': 0.5434791122862619, 'colsample_bytree': 0.5400599657796463, 'gamma': 0.0571687844109675, 'lambda': 2.179123599656312}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:24,574] Trial 54 finished with value: 1309.7032713596209 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.07460430514483789, 'subsample': 0.7313022188001704, 'colsample_bytree': 0.6075006011133769, 'gamma': 0.040302681865582994, 'lambda': 2.488624375576861}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:26,481] Trial 55 finished with value: 1309.6886530599036 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.1079822881731692, 'subsample': 0.5250661341927791, 'colsample_bytree': 0.5600002688712542, 'gamma': 0.11354575175660778, 'lambda': 1.9763855981927896}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:29,580] Trial 56 finished with value: 1309.5934942965973 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.1274066539887627, 'subsample': 0.5797347430073501, 'colsample_bytree': 0.6676107718630586, 'gamma': 0.22601248965425175, 'lambda': 4.314767553179344}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:33,788] Trial 57 finished with value: 1309.5870416009025 and parameters: {'n_estimators': 400, 'max_depth': 12, 'learning_rate': 0.1431732115820093, 'subsample': 0.549215361966642, 'colsample_bytree': 0.8744660583844833, 'gamma': 0.08679172379811831, 'lambda': 3.1596144399485695}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:36,354] Trial 58 finished with value: 1309.5896488921262 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.15512055199575242, 'subsample': 0.9310074273410007, 'colsample_bytree': 0.7036890054135194, 'gamma': 0.33371347400718065, 'lambda': 8.21000689735125}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:38,262] Trial 59 finished with value: 1309.619145086837 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.1892403287858664, 'subsample': 0.6654664444227475, 'colsample_bytree': 0.9351891801210983, 'gamma': 0.2934123657050248, 'lambda': 3.5328707599088998}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:41,480] Trial 60 finished with value: 1309.5832796748969 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.1331504220307171, 'subsample': 0.8256875725207252, 'colsample_bytree': 0.809929754803599, 'gamma': 0.187441760281011, 'lambda': 5.1936705735051145}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:44,096] Trial 61 finished with value: 1309.5731413251094 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.16576462950981682, 'subsample': 0.6851769333924461, 'colsample_bytree': 0.7380142554561819, 'gamma': 0.3713084796177354, 'lambda': 9.535051980767344}. Best is trial 32 with value: 1309.560468341378.
# [I 2025-04-08 23:35:46,605] Trial 62 finished with value: 1309.558352362702 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.16537605611392886, 'subsample': 0.7120774119198211, 'colsample_bytree': 0.7333301575329406, 'gamma': 0.4131906893240965, 'lambda': 9.438635898137541}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:35:49,172] Trial 63 finished with value: 1309.5888304228574 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.194343579446165, 'subsample': 0.7508498678094863, 'colsample_bytree': 0.6336867553071498, 'gamma': 0.4312141711124181, 'lambda': 9.108394197794413}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:35:51,090] Trial 64 finished with value: 1309.6088501105296 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.1765699222640121, 'subsample': 0.7140224669194684, 'colsample_bytree': 0.6562050014004029, 'gamma': 0.26183331543532506, 'lambda': 9.782086798729662}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:35:56,851] Trial 65 finished with value: 1309.6256852037254 and parameters: {'n_estimators': 700, 'max_depth': 9, 'learning_rate': 0.20773324798203538, 'subsample': 0.5132277001165335, 'colsample_bytree': 0.7848608656535074, 'gamma': 0.4044324306513033, 'lambda': 9.985404284766703}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:00,165] Trial 66 finished with value: 1309.5901636660321 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.14057220062045928, 'subsample': 0.5312263280611146, 'colsample_bytree': 0.5250237183625411, 'gamma': 0.45321038225683385, 'lambda': 8.20064157638584}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:02,180] Trial 67 finished with value: 1309.6368711615196 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.11457612759179206, 'subsample': 0.5571958802888962, 'colsample_bytree': 0.6961757757006759, 'gamma': 0.34392536543691643, 'lambda': 7.258932173059813}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:06,235] Trial 68 finished with value: 1309.5895984715894 and parameters: {'n_estimators': 400, 'max_depth': 12, 'learning_rate': 0.0939416191351809, 'subsample': 0.7380374856975966, 'colsample_bytree': 0.9749208441859426, 'gamma': 0.4308454971260116, 'lambda': 4.850640264415338}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:08,864] Trial 69 finished with value: 1309.5952267990313 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.14812831649100874, 'subsample': 0.6866511334345199, 'colsample_bytree': 0.577248882790261, 'gamma': 0.3143088295988621, 'lambda': 5.557143009922036}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:11,510] Trial 70 finished with value: 1309.5677273870185 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.1604614965793247, 'subsample': 0.7148939938401089, 'colsample_bytree': 0.7640260411463229, 'gamma': 0.3861808805851803, 'lambda': 2.6678568666119595}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:14,156] Trial 71 finished with value: 1309.580803754506 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.16227837796409122, 'subsample': 0.7636240177772182, 'colsample_bytree': 0.7513151133165858, 'gamma': 0.38675998900983094, 'lambda': 2.732380746942404}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:17,148] Trial 72 finished with value: 1309.6083488887768 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.17584714270843166, 'subsample': 0.7192840550793272, 'colsample_bytree': 0.8045657603163408, 'gamma': 0.4849949925204078, 'lambda': 1.823957084362438}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:19,782] Trial 73 finished with value: 1309.5984436595231 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.1350344741185998, 'subsample': 0.7892083488188266, 'colsample_bytree': 0.723092702687155, 'gamma': 0.21730464314344689, 'lambda': 9.364703156084113}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:21,749] Trial 74 finished with value: 1309.6091242834905 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.14991943291262644, 'subsample': 0.7431273233530467, 'colsample_bytree': 0.7593247702154216, 'gamma': 0.4272677137499598, 'lambda': 3.6401622977503822}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:24,367] Trial 75 finished with value: 1312.1575966231364 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.014686871785816707, 'subsample': 0.6442403293229629, 'colsample_bytree': 0.8274085253046515, 'gamma': 0.3893225471428939, 'lambda': 3.209729264809895}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:26,384] Trial 76 finished with value: 1309.6455353372871 and parameters: {'n_estimators': 100, 'max_depth': 12, 'learning_rate': 0.10448937191690139, 'subsample': 0.5704746166683141, 'colsample_bytree': 0.7048992857043934, 'gamma': 0.478838303720489, 'lambda': 1.1256744070232103}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:29,734] Trial 77 finished with value: 1309.5829714795584 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.1582007259858324, 'subsample': 0.7007736184172022, 'colsample_bytree': 0.7729290726174093, 'gamma': 0.4050694917808429, 'lambda': 7.692667979630256}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:32,700] Trial 78 finished with value: 1309.5905616084951 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.12661561951664002, 'subsample': 0.5944820047806053, 'colsample_bytree': 0.5385295903671387, 'gamma': 0.16522463865817227, 'lambda': 8.827260891886509}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:35,215] Trial 79 finished with value: 1309.5974137046937 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.16669610385025685, 'subsample': 0.625933524470914, 'colsample_bytree': 0.6001754266112418, 'gamma': 0.2806376652009179, 'lambda': 4.184465710165435}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:37,688] Trial 80 finished with value: 1309.592066172517 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.1904640507607831, 'subsample': 0.6708334458389442, 'colsample_bytree': 0.7996811474839413, 'gamma': 0.3691249513996629, 'lambda': 5.8639497082733065}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:40,210] Trial 81 finished with value: 1309.574731636082 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.17669202833632117, 'subsample': 0.6863335972999824, 'colsample_bytree': 0.6892071218846179, 'gamma': 0.36645855743937233, 'lambda': 9.527767224094578}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:42,607] Trial 82 finished with value: 1309.5892176293808 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.1698582253431705, 'subsample': 0.7740188087412562, 'colsample_bytree': 0.7277941250586828, 'gamma': 0.37875451341232735, 'lambda': 8.424932495471666}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:44,278] Trial 83 finished with value: 1311.0104992638503 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.1396858380805987, 'subsample': 0.7131176418872849, 'colsample_bytree': 0.7420974658687121, 'gamma': 0.42004713857197606, 'lambda': 9.58722540982993}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:48,638] Trial 84 finished with value: 1309.6132525386245 and parameters: {'n_estimators': 600, 'max_depth': 6, 'learning_rate': 0.11869560502385439, 'subsample': 0.7010676637758404, 'colsample_bytree': 0.5138632635593421, 'gamma': 0.34926338019276293, 'lambda': 9.09214974142834}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:56,066] Trial 85 finished with value: 1309.586145109331 and parameters: {'n_estimators': 1000, 'max_depth': 9, 'learning_rate': 0.15315165606562448, 'subsample': 0.6583028091453081, 'colsample_bytree': 0.554861302962367, 'gamma': 0.06654400664097272, 'lambda': 2.5969318243989217}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:36:59,246] Trial 86 finished with value: 1309.5907458080708 and parameters: {'n_estimators': 300, 'max_depth': 11, 'learning_rate': 0.16097128451616285, 'subsample': 0.7238981812571776, 'colsample_bytree': 0.8815900174952761, 'gamma': 0.4022649712684716, 'lambda': 3.8075421252057495}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:37:01,589] Trial 87 finished with value: 1309.5713101409522 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.20031211882858235, 'subsample': 0.6824981109004896, 'colsample_bytree': 0.7149655711184064, 'gamma': 0.0477796590796205, 'lambda': 3.4133240246689356}. Best is trial 62 with value: 1309.558352362702.
# [I 2025-04-08 23:37:04,016] Trial 88 finished with value: 1309.5582835080438 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.2169767883891455, 'subsample': 0.5409781676584561, 'colsample_bytree': 0.9210958544010214, 'gamma': 0.046212658942996004, 'lambda': 3.39304066136461}. Best is trial 88 with value: 1309.5582835080438.
# [I 2025-04-08 23:37:06,367] Trial 89 finished with value: 1309.5837381454594 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.2313741871867436, 'subsample': 0.6094087841663602, 'colsample_bytree': 0.9233478389258458, 'gamma': 0.048224956215963094, 'lambda': 3.2490363129406843}. Best is trial 88 with value: 1309.5582835080438.
# [I 2025-04-08 23:37:08,057] Trial 90 finished with value: 1309.5813789873935 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.2926085621334557, 'subsample': 0.5103980012502581, 'colsample_bytree': 0.9544460786444031, 'gamma': 0.004942526774084806, 'lambda': 2.87684729722914}. Best is trial 88 with value: 1309.5582835080438.
# [I 2025-04-08 23:37:10,358] Trial 91 finished with value: 1309.5815228204415 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.2200997261238003, 'subsample': 0.5341233797330116, 'colsample_bytree': 0.9050406664689026, 'gamma': 0.0267365431267665, 'lambda': 4.500667202459106}. Best is trial 88 with value: 1309.5582835080438.
# [I 2025-04-08 23:37:12,710] Trial 92 finished with value: 1309.5515493771538 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.21328669214955887, 'subsample': 0.5612422229400509, 'colsample_bytree': 0.7154256892399239, 'gamma': 0.046961219171458304, 'lambda': 3.4532788992701575}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:15,101] Trial 93 finished with value: 1309.5559013170214 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.21326392162293079, 'subsample': 0.5598022418950024, 'colsample_bytree': 0.7126751959194304, 'gamma': 0.08929470968230849, 'lambda': 3.396312272219812}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:17,409] Trial 94 finished with value: 1309.583114878978 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.21194094670904276, 'subsample': 0.5801122123854595, 'colsample_bytree': 0.7165056253798056, 'gamma': 0.08227755556784054, 'lambda': 3.4408579407476187}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:19,734] Trial 95 finished with value: 1309.5550354365425 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.2019870404516977, 'subsample': 0.5599399640792916, 'colsample_bytree': 0.7528035866660349, 'gamma': 0.04477989513235839, 'lambda': 4.0501751450119725}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:22,565] Trial 96 finished with value: 1309.6116113010944 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.23489939751372987, 'subsample': 0.5568570965538557, 'colsample_bytree': 0.7923128437755123, 'gamma': 0.018810554619245093, 'lambda': 3.857319110764495}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:24,306] Trial 97 finished with value: 1309.6233356682033 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.21521018725212807, 'subsample': 0.5605465633964748, 'colsample_bytree': 0.7666722060475879, 'gamma': 0.11341603839077682, 'lambda': 4.157833607220941}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:26,595] Trial 98 finished with value: 1309.5736745264753 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.2261010701437992, 'subsample': 0.5405042483866328, 'colsample_bytree': 0.747534442576439, 'gamma': 0.13664821410538716, 'lambda': 2.9700973956464956}. Best is trial 92 with value: 1309.5515493771538.
# [I 2025-04-08 23:37:29,423] Trial 99 finished with value: 1309.630123709695 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.2516904669975862, 'subsample': 0.5193463449484867, 'colsample_bytree': 0.8479467177024169, 'gamma': 0.09508150299248576, 'lambda': 4.605795907923185}. Best is trial 92 with value: 1309.5515493771538.
# {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.21328669214955887, 'subsample': 0.5612422229400509, 'colsample_bytree': 0.7154256892399239, 'gamma': 0.046961219171458304, 'lambda': 3.4532788992701575}

# %%
final_model = xgb.XGBRegressor(**study.best_params, tree_method="hist", objective="reg:squarederror", device="cuda", eval_metric="rmse")
y_train_log = training_set['days_since_user_ordered_product']

final_model.fit(training_set.drop(['days_since_user_ordered_product'], axis=1), y_train_log)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7154256892399239, device='cuda',
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric='rmse', feature_types=None, feature_weights=None,
#              gamma=0.046961219171458304, grow_policy=None, importance_type=None,
#              interaction_constraints=None, lambda=3.4532788992701575,
#              learning_rate=0.21328669214955887, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None, ...)

# %%
y_pred = final_model.predict(testing_set.drop(['days_since_user_ordered_product'], axis=1))
score = mean_squared_error(testing_set['days_since_user_ordered_product'], y_pred)
print(score)
# Out:
# 1299.893176384557

# %%
y = testing_set['days_since_user_ordered_product']
y_pred = final_model.predict(testing_set.drop(['days_since_user_ordered_product'], axis=1))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

print(f"MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R²: {r2}")
# Out:
# MSE: 1299.893176384557, RMSE: 36.05403134719552, MAE: 22.946104065436796, R²: 0.03671450471042037
